# %% [markdown]
# # Jupyter Notebook: Load IRS SOI Net Migration Data to Database

# %%
# Jupyter Notebook: Load IRS Net Migration to economic_indicators Table

import os
from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.engine import URL

# Load environment variables
load_dotenv()

# Database config
DB_NAME = os.environ["DB_NAME"]
DB_USER = os.environ["DB_USER"]
DB_PASSWORD = os.environ["DB_PASSWORD"]
DB_HOST = os.environ.get("DB_HOST", "localhost")
DB_PORT = os.environ.get("DB_PORT", "5432")

# Connect to database
connection_url = URL.create(
    "postgresql+psycopg2",
    username=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT,
    database=DB_NAME,
)
engine = create_engine(connection_url, echo=True)

# ----------------------------------------
# Load IRS Migration Data for CO and TX (Multiple Years)
# ----------------------------------------

def fetch_irs_net_migration(file_year):
    short_prev = str(file_year - 1)[-2:]
    short_curr = str(file_year)[-2:]
    url = f"https://www.irs.gov/pub/irs-soi/countyinflow{short_prev}{short_curr}.csv"
    try:
        df = pd.read_csv(url)
    except Exception as e:
        print(f"❌ Failed to fetch {url}: {e}")
        return pd.DataFrame()

    if not set(["y2_statefips", "y2_countyfips", "n2"]).issubset(df.columns):
        print(f"⚠️ Unexpected format in {url}, skipping")
        return pd.DataFrame()

    df = df[df["y2_statefips"].isin([8, 48])]
    df = df.groupby(["y2_statefips", "y2_countyfips"]).agg({"n2": "sum"}).reset_index()
    df["county_fips"] = df["y2_statefips"].astype(str).str.zfill(2) + df["y2_countyfips"].astype(str).str.zfill(3)
    df["year"] = file_year
    df.rename(columns={"n2": "net_migration"}, inplace=True)
    return df[["county_fips", "year", "net_migration"]]

# Fetch multiple years
years = [2016, 2017, 2018, 2019, 2020, 2021]
all_years = [fetch_irs_net_migration(y) for y in years]
net_migration_df = pd.concat([df for df in all_years if not df.empty])

# Check for matches in economic_indicators
with engine.begin() as conn:
    result = conn.execute(text("SELECT county_fips, year FROM economic_indicators"))
    existing_keys = set((row["county_fips"], row["year"]) for row in result.mappings())

# Keep only matching rows
net_migration_df = net_migration_df[net_migration_df.apply(lambda row: (row["county_fips"], row["year"]) in existing_keys, axis=1)]

# Update economic_indicators with net_migration
with engine.begin() as conn:
    for _, row in net_migration_df.iterrows():
        conn.execute(
            text("""
                UPDATE economic_indicators
                SET net_migration = :net_migration
                WHERE county_fips = :county_fips AND year = :year
            """),
            {
                "net_migration": int(row["net_migration"]),
                "county_fips": row["county_fips"],
                "year": row["year"]
            }
        )

print("✅ IRS net migration data for 2016–2020 loaded into economic_indicators table.")
# Out:
# 2025-04-19 11:30:33,776 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-04-19 11:30:33,776 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-19 11:30:33,777 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-04-19 11:30:33,777 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-19 11:30:33,778 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-04-19 11:30:33,778 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-19 11:30:33,779 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-19 11:30:33,779 INFO sqlalchemy.engine.Engine SELECT county_fips, year FROM economic_indicators
# 2025-04-19 11:30:33,779 INFO sqlalchemy.engine.Engine [generated in 0.00026s] {}
# 2025-04-19 11:30:33,783 INFO sqlalchemy.engine.Engine COMMIT
# 2025-04-19 11:30:33,793 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-19 11:30:33,793 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,793 INFO sqlalchemy.engine.Engine [generated in 0.00030s] {'net_migration': 548573, 'county_fips': '08001', 'year': 2016}
# 2025-04-19 11:30:33,794 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,795 INFO sqlalchemy.engine.Engine [cached since 0.001391s ago] {'net_migration': 15235, 'county_fips': '08003', 'year': 2016}
# 2025-04-19 11:30:33,795 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,796 INFO sqlalchemy.engine.Engine [cached since 0.002357s ago] {'net_migration': 707780, 'county_fips': '08005', 'year': 2016}
# 2025-04-19 11:30:33,796 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,796 INFO sqlalchemy.engine.Engine [cached since 0.003242s ago] {'net_migration': 13947, 'county_fips': '08007', 'year': 2016}
# 2025-04-19 11:30:33,797 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,797 INFO sqlalchemy.engine.Engine [cached since 0.00424s ago] {'net_migration': 2979, 'county_fips': '08009', 'year': 2016}
# 2025-04-19 11:30:33,798 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,798 INFO sqlalchemy.engine.Engine [cached since 0.005136s ago] {'net_migration': 3460, 'county_fips': '08011', 'year': 2016}
# 2025-04-19 11:30:33,799 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,799 INFO sqlalchemy.engine.Engine [cached since 0.005952s ago] {'net_migration': 324276, 'county_fips': '08013', 'year': 2016}
# 2025-04-19 11:30:33,800 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,800 INFO sqlalchemy.engine.Engine [cached since 0.006842s ago] {'net_migration': 85712, 'county_fips': '08014', 'year': 2016}
# 2025-04-19 11:30:33,801 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,801 INFO sqlalchemy.engine.Engine [cached since 0.007674s ago] {'net_migration': 19465, 'county_fips': '08015', 'year': 2016}
# 2025-04-19 11:30:33,802 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,802 INFO sqlalchemy.engine.Engine [cached since 0.008574s ago] {'net_migration': 1430, 'county_fips': '08017', 'year': 2016}
# 2025-04-19 11:30:33,803 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,803 INFO sqlalchemy.engine.Engine [cached since 0.009749s ago] {'net_migration': 9684, 'county_fips': '08019', 'year': 2016}
# 2025-04-19 11:30:33,804 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,804 INFO sqlalchemy.engine.Engine [cached since 0.01068s ago] {'net_migration': 6759, 'county_fips': '08021', 'year': 2016}
# 2025-04-19 11:30:33,805 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,805 INFO sqlalchemy.engine.Engine [cached since 0.01159s ago] {'net_migration': 2932, 'county_fips': '08023', 'year': 2016}
# 2025-04-19 11:30:33,805 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,806 INFO sqlalchemy.engine.Engine [cached since 0.01245s ago] {'net_migration': 2486, 'county_fips': '08025', 'year': 2016}
# 2025-04-19 11:30:33,806 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,806 INFO sqlalchemy.engine.Engine [cached since 0.01325s ago] {'net_migration': 5039, 'county_fips': '08027', 'year': 2016}
# 2025-04-19 11:30:33,807 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,807 INFO sqlalchemy.engine.Engine [cached since 0.01412s ago] {'net_migration': 29692, 'county_fips': '08029', 'year': 2016}
# 2025-04-19 11:30:33,808 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,808 INFO sqlalchemy.engine.Engine [cached since 0.01511s ago] {'net_migration': 732075, 'county_fips': '08031', 'year': 2016}
# 2025-04-19 11:30:33,809 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,809 INFO sqlalchemy.engine.Engine [cached since 0.01593s ago] {'net_migration': 1763, 'county_fips': '08033', 'year': 2016}
# 2025-04-19 11:30:33,810 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,810 INFO sqlalchemy.engine.Engine [cached since 0.01692s ago] {'net_migration': 385272, 'county_fips': '08035', 'year': 2016}
# 2025-04-19 11:30:33,811 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,811 INFO sqlalchemy.engine.Engine [cached since 0.01819s ago] {'net_migration': 59430, 'county_fips': '08037', 'year': 2016}
# 2025-04-19 11:30:33,812 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,813 INFO sqlalchemy.engine.Engine [cached since 0.01963s ago] {'net_migration': 28362, 'county_fips': '08039', 'year': 2016}
# 2025-04-19 11:30:33,814 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,814 INFO sqlalchemy.engine.Engine [cached since 0.02105s ago] {'net_migration': 739043, 'county_fips': '08041', 'year': 2016}
# 2025-04-19 11:30:33,815 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,815 INFO sqlalchemy.engine.Engine [cached since 0.02222s ago] {'net_migration': 39183, 'county_fips': '08043', 'year': 2016}
# 2025-04-19 11:30:33,816 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,817 INFO sqlalchemy.engine.Engine [cached since 0.02346s ago] {'net_migration': 61133, 'county_fips': '08045', 'year': 2016}
# 2025-04-19 11:30:33,817 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,818 INFO sqlalchemy.engine.Engine [cached since 0.02465s ago] {'net_migration': 5936, 'county_fips': '08047', 'year': 2016}
# 2025-04-19 11:30:33,819 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,819 INFO sqlalchemy.engine.Engine [cached since 0.02582s ago] {'net_migration': 15979, 'county_fips': '08049', 'year': 2016}
# 2025-04-19 11:30:33,820 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,820 INFO sqlalchemy.engine.Engine [cached since 0.0269s ago] {'net_migration': 15686, 'county_fips': '08051', 'year': 2016}
# 2025-04-19 11:30:33,821 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,821 INFO sqlalchemy.engine.Engine [cached since 0.02801s ago] {'net_migration': 671, 'county_fips': '08053', 'year': 2016}
# 2025-04-19 11:30:33,822 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,822 INFO sqlalchemy.engine.Engine [cached since 0.02911s ago] {'net_migration': 5940, 'county_fips': '08055', 'year': 2016}
# 2025-04-19 11:30:33,823 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,823 INFO sqlalchemy.engine.Engine [cached since 0.03025s ago] {'net_migration': 1330, 'county_fips': '08057', 'year': 2016}
# 2025-04-19 11:30:33,824 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,825 INFO sqlalchemy.engine.Engine [cached since 0.03162s ago] {'net_migration': 620872, 'county_fips': '08059', 'year': 2016}
# 2025-04-19 11:30:33,826 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,826 INFO sqlalchemy.engine.Engine [cached since 0.03269s ago] {'net_migration': 985, 'county_fips': '08061', 'year': 2016}
# 2025-04-19 11:30:33,827 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,827 INFO sqlalchemy.engine.Engine [cached since 0.03376s ago] {'net_migration': 7355, 'county_fips': '08063', 'year': 2016}
# 2025-04-19 11:30:33,828 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,828 INFO sqlalchemy.engine.Engine [cached since 0.03482s ago] {'net_migration': 7710, 'county_fips': '08065', 'year': 2016}
# 2025-04-19 11:30:33,829 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,829 INFO sqlalchemy.engine.Engine [cached since 0.03586s ago] {'net_migration': 54247, 'county_fips': '08067', 'year': 2016}
# 2025-04-19 11:30:33,830 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,830 INFO sqlalchemy.engine.Engine [cached since 0.03687s ago] {'net_migration': 341432, 'county_fips': '08069', 'year': 2016}
# 2025-04-19 11:30:33,831 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,831 INFO sqlalchemy.engine.Engine [cached since 0.03798s ago] {'net_migration': 12698, 'county_fips': '08071', 'year': 2016}
# 2025-04-19 11:30:33,832 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,832 INFO sqlalchemy.engine.Engine [cached since 0.03915s ago] {'net_migration': 4599, 'county_fips': '08073', 'year': 2016}
# 2025-04-19 11:30:33,833 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,833 INFO sqlalchemy.engine.Engine [cached since 0.04028s ago] {'net_migration': 18042, 'county_fips': '08075', 'year': 2016}
# 2025-04-19 11:30:33,834 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,835 INFO sqlalchemy.engine.Engine [cached since 0.04139s ago] {'net_migration': 141272, 'county_fips': '08077', 'year': 2016}
# 2025-04-19 11:30:33,835 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,836 INFO sqlalchemy.engine.Engine [cached since 0.04248s ago] {'net_migration': 687, 'county_fips': '08079', 'year': 2016}
# 2025-04-19 11:30:33,836 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,837 INFO sqlalchemy.engine.Engine [cached since 0.04366s ago] {'net_migration': 13671, 'county_fips': '08081', 'year': 2016}
# 2025-04-19 11:30:33,838 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,838 INFO sqlalchemy.engine.Engine [cached since 0.04473s ago] {'net_migration': 25836, 'county_fips': '08083', 'year': 2016}
# 2025-04-19 11:30:33,839 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,839 INFO sqlalchemy.engine.Engine [cached since 0.04579s ago] {'net_migration': 41895, 'county_fips': '08085', 'year': 2016}
# 2025-04-19 11:30:33,840 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,840 INFO sqlalchemy.engine.Engine [cached since 0.04685s ago] {'net_migration': 28894, 'county_fips': '08087', 'year': 2016}
# 2025-04-19 11:30:33,841 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,841 INFO sqlalchemy.engine.Engine [cached since 0.04789s ago] {'net_migration': 16659, 'county_fips': '08089', 'year': 2016}
# 2025-04-19 11:30:33,842 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,842 INFO sqlalchemy.engine.Engine [cached since 0.04891s ago] {'net_migration': 5642, 'county_fips': '08091', 'year': 2016}
# 2025-04-19 11:30:33,843 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,843 INFO sqlalchemy.engine.Engine [cached since 0.04993s ago] {'net_migration': 17771, 'county_fips': '08093', 'year': 2016}
# 2025-04-19 11:30:33,844 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,844 INFO sqlalchemy.engine.Engine [cached since 0.05101s ago] {'net_migration': 4228, 'county_fips': '08095', 'year': 2016}
# 2025-04-19 11:30:33,845 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,845 INFO sqlalchemy.engine.Engine [cached since 0.05208s ago] {'net_migration': 18403, 'county_fips': '08097', 'year': 2016}
# 2025-04-19 11:30:33,846 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,846 INFO sqlalchemy.engine.Engine [cached since 0.05313s ago] {'net_migration': 11203, 'county_fips': '08099', 'year': 2016}
# 2025-04-19 11:30:33,847 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,847 INFO sqlalchemy.engine.Engine [cached since 0.05419s ago] {'net_migration': 144915, 'county_fips': '08101', 'year': 2016}
# 2025-04-19 11:30:33,848 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,848 INFO sqlalchemy.engine.Engine [cached since 0.05528s ago] {'net_migration': 6420, 'county_fips': '08103', 'year': 2016}
# 2025-04-19 11:30:33,849 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,850 INFO sqlalchemy.engine.Engine [cached since 0.05645s ago] {'net_migration': 13171, 'county_fips': '08105', 'year': 2016}
# 2025-04-19 11:30:33,850 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,851 INFO sqlalchemy.engine.Engine [cached since 0.05739s ago] {'net_migration': 26603, 'county_fips': '08107', 'year': 2016}
# 2025-04-19 11:30:33,851 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,851 INFO sqlalchemy.engine.Engine [cached since 0.05831s ago] {'net_migration': 4111, 'county_fips': '08109', 'year': 2016}
# 2025-04-19 11:30:33,852 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,853 INFO sqlalchemy.engine.Engine [cached since 0.05932s ago] {'net_migration': 403, 'county_fips': '08111', 'year': 2016}
# 2025-04-19 11:30:33,853 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,853 INFO sqlalchemy.engine.Engine [cached since 0.06021s ago] {'net_migration': 8718, 'county_fips': '08113', 'year': 2016}
# 2025-04-19 11:30:33,854 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,854 INFO sqlalchemy.engine.Engine [cached since 0.0611s ago] {'net_migration': 2287, 'county_fips': '08115', 'year': 2016}
# 2025-04-19 11:30:33,855 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,855 INFO sqlalchemy.engine.Engine [cached since 0.06196s ago] {'net_migration': 34662, 'county_fips': '08117', 'year': 2016}
# 2025-04-19 11:30:33,856 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,856 INFO sqlalchemy.engine.Engine [cached since 0.06288s ago] {'net_migration': 28532, 'county_fips': '08119', 'year': 2016}
# 2025-04-19 11:30:33,857 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,857 INFO sqlalchemy.engine.Engine [cached since 0.06384s ago] {'net_migration': 4358, 'county_fips': '08121', 'year': 2016}
# 2025-04-19 11:30:33,859 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,859 INFO sqlalchemy.engine.Engine [cached since 0.06612s ago] {'net_migration': 318087, 'county_fips': '08123', 'year': 2016}
# 2025-04-19 11:30:33,860 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,860 INFO sqlalchemy.engine.Engine [cached since 0.06698s ago] {'net_migration': 9894, 'county_fips': '08125', 'year': 2016}
# 2025-04-19 11:30:33,861 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,861 INFO sqlalchemy.engine.Engine [cached since 0.06801s ago] {'net_migration': 43228, 'county_fips': '48001', 'year': 2016}
# 2025-04-19 11:30:33,862 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,862 INFO sqlalchemy.engine.Engine [cached since 0.06888s ago] {'net_migration': 18467, 'county_fips': '48003', 'year': 2016}
# 2025-04-19 11:30:33,863 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,863 INFO sqlalchemy.engine.Engine [cached since 0.06996s ago] {'net_migration': 79292, 'county_fips': '48005', 'year': 2016}
# 2025-04-19 11:30:33,864 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,864 INFO sqlalchemy.engine.Engine [cached since 0.07101s ago] {'net_migration': 25965, 'county_fips': '48007', 'year': 2016}
# 2025-04-19 11:30:33,865 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,865 INFO sqlalchemy.engine.Engine [cached since 0.07209s ago] {'net_migration': 8687, 'county_fips': '48009', 'year': 2016}
# 2025-04-19 11:30:33,866 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,866 INFO sqlalchemy.engine.Engine [cached since 0.07328s ago] {'net_migration': 1963, 'county_fips': '48011', 'year': 2016}
# 2025-04-19 11:30:33,867 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,868 INFO sqlalchemy.engine.Engine [cached since 0.07464s ago] {'net_migration': 48436, 'county_fips': '48013', 'year': 2016}
# 2025-04-19 11:30:33,869 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,869 INFO sqlalchemy.engine.Engine [cached since 0.0757s ago] {'net_migration': 30652, 'county_fips': '48015', 'year': 2016}
# 2025-04-19 11:30:33,870 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,870 INFO sqlalchemy.engine.Engine [cached since 0.07666s ago] {'net_migration': 8067, 'county_fips': '48017', 'year': 2016}
# 2025-04-19 11:30:33,871 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,871 INFO sqlalchemy.engine.Engine [cached since 0.07761s ago] {'net_migration': 21122, 'county_fips': '48019', 'year': 2016}
# 2025-04-19 11:30:33,872 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,872 INFO sqlalchemy.engine.Engine [cached since 0.07856s ago] {'net_migration': 84796, 'county_fips': '48021', 'year': 2016}
# 2025-04-19 11:30:33,872 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,873 INFO sqlalchemy.engine.Engine [cached since 0.07945s ago] {'net_migration': 3170, 'county_fips': '48023', 'year': 2016}
# 2025-04-19 11:30:33,873 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,874 INFO sqlalchemy.engine.Engine [cached since 0.08035s ago] {'net_migration': 24294, 'county_fips': '48025', 'year': 2016}
# 2025-04-19 11:30:33,874 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,874 INFO sqlalchemy.engine.Engine [cached since 0.0813s ago] {'net_migration': 381310, 'county_fips': '48027', 'year': 2016}
# 2025-04-19 11:30:33,875 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,875 INFO sqlalchemy.engine.Engine [cached since 0.08213s ago] {'net_migration': 1761351, 'county_fips': '48029', 'year': 2016}
# 2025-04-19 11:30:33,876 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,876 INFO sqlalchemy.engine.Engine [cached since 0.08292s ago] {'net_migration': 11628, 'county_fips': '48031', 'year': 2016}
# 2025-04-19 11:30:33,877 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,877 INFO sqlalchemy.engine.Engine [cached since 0.08375s ago] {'net_migration': 643, 'county_fips': '48033', 'year': 2016}
# 2025-04-19 11:30:33,878 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,878 INFO sqlalchemy.engine.Engine [cached since 0.08453s ago] {'net_migration': 17767, 'county_fips': '48035', 'year': 2016}
# 2025-04-19 11:30:33,878 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,879 INFO sqlalchemy.engine.Engine [cached since 0.08544s ago] {'net_migration': 87907, 'county_fips': '48037', 'year': 2016}
# 2025-04-19 11:30:33,879 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,880 INFO sqlalchemy.engine.Engine [cached since 0.0866s ago] {'net_migration': 357103, 'county_fips': '48039', 'year': 2016}
# 2025-04-19 11:30:33,880 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,881 INFO sqlalchemy.engine.Engine [cached since 0.08754s ago] {'net_migration': 171926, 'county_fips': '48041', 'year': 2016}
# 2025-04-19 11:30:33,881 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,882 INFO sqlalchemy.engine.Engine [cached since 0.08838s ago] {'net_migration': 9537, 'county_fips': '48043', 'year': 2016}
# 2025-04-19 11:30:33,882 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,882 INFO sqlalchemy.engine.Engine [cached since 0.08917s ago] {'net_migration': 1373, 'county_fips': '48045', 'year': 2016}
# 2025-04-19 11:30:33,883 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,883 INFO sqlalchemy.engine.Engine [cached since 0.08999s ago] {'net_migration': 6247, 'county_fips': '48047', 'year': 2016}
# 2025-04-19 11:30:33,884 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,884 INFO sqlalchemy.engine.Engine [cached since 0.09084s ago] {'net_migration': 35115, 'county_fips': '48049', 'year': 2016}
# 2025-04-19 11:30:33,885 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,885 INFO sqlalchemy.engine.Engine [cached since 0.09169s ago] {'net_migration': 17612, 'county_fips': '48051', 'year': 2016}
# 2025-04-19 11:30:33,886 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,886 INFO sqlalchemy.engine.Engine [cached since 0.09303s ago] {'net_migration': 49205, 'county_fips': '48053', 'year': 2016}
# 2025-04-19 11:30:33,887 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,887 INFO sqlalchemy.engine.Engine [cached since 0.09426s ago] {'net_migration': 41428, 'county_fips': '48055', 'year': 2016}
# 2025-04-19 11:30:33,888 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,889 INFO sqlalchemy.engine.Engine [cached since 0.09541s ago] {'net_migration': 21052, 'county_fips': '48057', 'year': 2016}
# 2025-04-19 11:30:33,889 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,890 INFO sqlalchemy.engine.Engine [cached since 0.09653s ago] {'net_migration': 13707, 'county_fips': '48059', 'year': 2016}
# 2025-04-19 11:30:33,890 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,891 INFO sqlalchemy.engine.Engine [cached since 0.09753s ago] {'net_migration': 364529, 'county_fips': '48061', 'year': 2016}
# 2025-04-19 11:30:33,891 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,892 INFO sqlalchemy.engine.Engine [cached since 0.09855s ago] {'net_migration': 12684, 'county_fips': '48063', 'year': 2016}
# 2025-04-19 11:30:33,892 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,893 INFO sqlalchemy.engine.Engine [cached since 0.09955s ago] {'net_migration': 6304, 'county_fips': '48065', 'year': 2016}
# 2025-04-19 11:30:33,893 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,894 INFO sqlalchemy.engine.Engine [cached since 0.1005s ago] {'net_migration': 27716, 'county_fips': '48067', 'year': 2016}
# 2025-04-19 11:30:33,894 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,895 INFO sqlalchemy.engine.Engine [cached since 0.1015s ago] {'net_migration': 7371, 'county_fips': '48069', 'year': 2016}
# 2025-04-19 11:30:33,895 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,896 INFO sqlalchemy.engine.Engine [cached since 0.1024s ago] {'net_migration': 48074, 'county_fips': '48071', 'year': 2016}
# 2025-04-19 11:30:33,896 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,896 INFO sqlalchemy.engine.Engine [cached since 0.1033s ago] {'net_migration': 47091, 'county_fips': '48073', 'year': 2016}
# 2025-04-19 11:30:33,897 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,897 INFO sqlalchemy.engine.Engine [cached since 0.1042s ago] {'net_migration': 5282, 'county_fips': '48075', 'year': 2016}
# 2025-04-19 11:30:33,898 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,898 INFO sqlalchemy.engine.Engine [cached since 0.1051s ago] {'net_migration': 10135, 'county_fips': '48077', 'year': 2016}
# 2025-04-19 11:30:33,899 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,899 INFO sqlalchemy.engine.Engine [cached since 0.106s ago] {'net_migration': 2778, 'county_fips': '48079', 'year': 2016}
# 2025-04-19 11:30:33,900 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,900 INFO sqlalchemy.engine.Engine [cached since 0.1071s ago] {'net_migration': 3119, 'county_fips': '48081', 'year': 2016}
# 2025-04-19 11:30:33,901 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,901 INFO sqlalchemy.engine.Engine [cached since 0.108s ago] {'net_migration': 7585, 'county_fips': '48083', 'year': 2016}
# 2025-04-19 11:30:33,902 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,902 INFO sqlalchemy.engine.Engine [cached since 0.1089s ago] {'net_migration': 1039817, 'county_fips': '48085', 'year': 2016}
# 2025-04-19 11:30:33,903 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,903 INFO sqlalchemy.engine.Engine [cached since 0.1098s ago] {'net_migration': 2816, 'county_fips': '48087', 'year': 2016}
# 2025-04-19 11:30:33,904 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,904 INFO sqlalchemy.engine.Engine [cached since 0.1109s ago] {'net_migration': 20249, 'county_fips': '48089', 'year': 2016}
# 2025-04-19 11:30:33,905 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,905 INFO sqlalchemy.engine.Engine [cached since 0.1119s ago] {'net_migration': 155952, 'county_fips': '48091', 'year': 2016}
# 2025-04-19 11:30:33,906 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,906 INFO sqlalchemy.engine.Engine [cached since 0.1129s ago] {'net_migration': 12576, 'county_fips': '48093', 'year': 2016}
# 2025-04-19 11:30:33,907 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,907 INFO sqlalchemy.engine.Engine [cached since 0.1138s ago] {'net_migration': 2430, 'county_fips': '48095', 'year': 2016}
# 2025-04-19 11:30:33,908 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,908 INFO sqlalchemy.engine.Engine [cached since 0.1147s ago] {'net_migration': 40805, 'county_fips': '48097', 'year': 2016}
# 2025-04-19 11:30:33,908 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,909 INFO sqlalchemy.engine.Engine [cached since 0.1155s ago] {'net_migration': 85151, 'county_fips': '48099', 'year': 2016}
# 2025-04-19 11:30:33,909 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,910 INFO sqlalchemy.engine.Engine [cached since 0.1164s ago] {'net_migration': 1272, 'county_fips': '48101', 'year': 2016}
# 2025-04-19 11:30:33,910 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,910 INFO sqlalchemy.engine.Engine [cached since 0.1172s ago] {'net_migration': 4826, 'county_fips': '48103', 'year': 2016}
# 2025-04-19 11:30:33,911 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,911 INFO sqlalchemy.engine.Engine [cached since 0.118s ago] {'net_migration': 3668, 'county_fips': '48105', 'year': 2016}
# 2025-04-19 11:30:33,912 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,912 INFO sqlalchemy.engine.Engine [cached since 0.119s ago] {'net_migration': 5493, 'county_fips': '48107', 'year': 2016}
# 2025-04-19 11:30:33,913 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,913 INFO sqlalchemy.engine.Engine [cached since 0.1198s ago] {'net_migration': 2299, 'county_fips': '48109', 'year': 2016}
# 2025-04-19 11:30:33,914 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,914 INFO sqlalchemy.engine.Engine [cached since 0.1207s ago] {'net_migration': 9263, 'county_fips': '48111', 'year': 2016}
# 2025-04-19 11:30:33,915 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,915 INFO sqlalchemy.engine.Engine [cached since 0.1217s ago] {'net_migration': 2465658, 'county_fips': '48113', 'year': 2016}
# 2025-04-19 11:30:33,916 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,916 INFO sqlalchemy.engine.Engine [cached since 0.1226s ago] {'net_migration': 11351, 'county_fips': '48115', 'year': 2016}
# 2025-04-19 11:30:33,916 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:33,917 INFO sqlalchemy.engine.Engine [cached since 0.1235s ago] {'net_migration': 20055, 'county_fips': '48117', 'year': 2016}
# 2025-04-19 11:30:33,917 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# ...
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,593 INFO sqlalchemy.engine.Engine [cached since 1.8s ago] {'net_migration': 10473, 'county_fips': '48425', 'year': 2021}
# 2025-04-19 11:30:35,594 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,594 INFO sqlalchemy.engine.Engine [cached since 1.801s ago] {'net_migration': 57397, 'county_fips': '48427', 'year': 2021}
# 2025-04-19 11:30:35,595 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,596 INFO sqlalchemy.engine.Engine [cached since 1.802s ago] {'net_migration': 7646, 'county_fips': '48429', 'year': 2021}
# 2025-04-19 11:30:35,596 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,596 INFO sqlalchemy.engine.Engine [cached since 1.803s ago] {'net_migration': 1342, 'county_fips': '48431', 'year': 2021}
# 2025-04-19 11:30:35,597 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,598 INFO sqlalchemy.engine.Engine [cached since 1.804s ago] {'net_migration': 1174, 'county_fips': '48433', 'year': 2021}
# 2025-04-19 11:30:35,598 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,598 INFO sqlalchemy.engine.Engine [cached since 1.805s ago] {'net_migration': 3406, 'county_fips': '48435', 'year': 2021}
# 2025-04-19 11:30:35,599 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,599 INFO sqlalchemy.engine.Engine [cached since 1.806s ago] {'net_migration': 6105, 'county_fips': '48437', 'year': 2021}
# 2025-04-19 11:30:35,600 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,600 INFO sqlalchemy.engine.Engine [cached since 1.807s ago] {'net_migration': 2029227, 'county_fips': '48439', 'year': 2021}
# 2025-04-19 11:30:35,601 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,602 INFO sqlalchemy.engine.Engine [cached since 1.809s ago] {'net_migration': 139481, 'county_fips': '48441', 'year': 2021}
# 2025-04-19 11:30:35,602 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,603 INFO sqlalchemy.engine.Engine [cached since 1.81s ago] {'net_migration': 516, 'county_fips': '48443', 'year': 2021}
# 2025-04-19 11:30:35,603 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,604 INFO sqlalchemy.engine.Engine [cached since 1.811s ago] {'net_migration': 10352, 'county_fips': '48445', 'year': 2021}
# 2025-04-19 11:30:35,605 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,605 INFO sqlalchemy.engine.Engine [cached since 1.812s ago] {'net_migration': 1393, 'county_fips': '48447', 'year': 2021}
# 2025-04-19 11:30:35,606 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,606 INFO sqlalchemy.engine.Engine [cached since 1.813s ago] {'net_migration': 30910, 'county_fips': '48449', 'year': 2021}
# 2025-04-19 11:30:35,607 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,607 INFO sqlalchemy.engine.Engine [cached since 1.814s ago] {'net_migration': 111221, 'county_fips': '48451', 'year': 2021}
# 2025-04-19 11:30:35,608 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,608 INFO sqlalchemy.engine.Engine [cached since 1.815s ago] {'net_migration': 1223323, 'county_fips': '48453', 'year': 2021}
# 2025-04-19 11:30:35,609 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,609 INFO sqlalchemy.engine.Engine [cached since 1.816s ago] {'net_migration': 14351, 'county_fips': '48455', 'year': 2021}
# 2025-04-19 11:30:35,610 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,610 INFO sqlalchemy.engine.Engine [cached since 1.817s ago] {'net_migration': 19117, 'county_fips': '48457', 'year': 2021}
# 2025-04-19 11:30:35,610 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,611 INFO sqlalchemy.engine.Engine [cached since 1.817s ago] {'net_migration': 43661, 'county_fips': '48459', 'year': 2021}
# 2025-04-19 11:30:35,611 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,611 INFO sqlalchemy.engine.Engine [cached since 1.818s ago] {'net_migration': 3189, 'county_fips': '48461', 'year': 2021}
# 2025-04-19 11:30:35,612 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,612 INFO sqlalchemy.engine.Engine [cached since 1.819s ago] {'net_migration': 25412, 'county_fips': '48463', 'year': 2021}
# 2025-04-19 11:30:35,613 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,613 INFO sqlalchemy.engine.Engine [cached since 1.82s ago] {'net_migration': 49271, 'county_fips': '48465', 'year': 2021}
# 2025-04-19 11:30:35,614 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,614 INFO sqlalchemy.engine.Engine [cached since 1.821s ago] {'net_migration': 58954, 'county_fips': '48467', 'year': 2021}
# 2025-04-19 11:30:35,615 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,615 INFO sqlalchemy.engine.Engine [cached since 1.822s ago] {'net_migration': 84307, 'county_fips': '48469', 'year': 2021}
# 2025-04-19 11:30:35,615 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,616 INFO sqlalchemy.engine.Engine [cached since 1.823s ago] {'net_migration': 56771, 'county_fips': '48471', 'year': 2021}
# 2025-04-19 11:30:35,616 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,617 INFO sqlalchemy.engine.Engine [cached since 1.823s ago] {'net_migration': 59325, 'county_fips': '48473', 'year': 2021}
# 2025-04-19 11:30:35,618 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,618 INFO sqlalchemy.engine.Engine [cached since 1.825s ago] {'net_migration': 11722, 'county_fips': '48475', 'year': 2021}
# 2025-04-19 11:30:35,619 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,619 INFO sqlalchemy.engine.Engine [cached since 1.826s ago] {'net_migration': 34446, 'county_fips': '48477', 'year': 2021}
# 2025-04-19 11:30:35,620 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,620 INFO sqlalchemy.engine.Engine [cached since 1.827s ago] {'net_migration': 237876, 'county_fips': '48479', 'year': 2021}
# 2025-04-19 11:30:35,621 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,621 INFO sqlalchemy.engine.Engine [cached since 1.828s ago] {'net_migration': 40435, 'county_fips': '48481', 'year': 2021}
# 2025-04-19 11:30:35,622 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,622 INFO sqlalchemy.engine.Engine [cached since 1.829s ago] {'net_migration': 4488, 'county_fips': '48483', 'year': 2021}
# 2025-04-19 11:30:35,623 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,623 INFO sqlalchemy.engine.Engine [cached since 1.83s ago] {'net_migration': 119322, 'county_fips': '48485', 'year': 2021}
# 2025-04-19 11:30:35,623 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,624 INFO sqlalchemy.engine.Engine [cached since 1.83s ago] {'net_migration': 11638, 'county_fips': '48487', 'year': 2021}
# 2025-04-19 11:30:35,624 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,625 INFO sqlalchemy.engine.Engine [cached since 1.831s ago] {'net_migration': 16241, 'county_fips': '48489', 'year': 2021}
# 2025-04-19 11:30:35,625 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,626 INFO sqlalchemy.engine.Engine [cached since 1.832s ago] {'net_migration': 729386, 'county_fips': '48491', 'year': 2021}
# 2025-04-19 11:30:35,626 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,626 INFO sqlalchemy.engine.Engine [cached since 1.833s ago] {'net_migration': 56334, 'county_fips': '48493', 'year': 2021}
# 2025-04-19 11:30:35,627 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,627 INFO sqlalchemy.engine.Engine [cached since 1.834s ago] {'net_migration': 6817, 'county_fips': '48495', 'year': 2021}
# 2025-04-19 11:30:35,628 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,628 INFO sqlalchemy.engine.Engine [cached since 1.835s ago] {'net_migration': 80697, 'county_fips': '48497', 'year': 2021}
# 2025-04-19 11:30:35,629 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,629 INFO sqlalchemy.engine.Engine [cached since 1.836s ago] {'net_migration': 48758, 'county_fips': '48499', 'year': 2021}
# 2025-04-19 11:30:35,630 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,630 INFO sqlalchemy.engine.Engine [cached since 1.837s ago] {'net_migration': 8225, 'county_fips': '48501', 'year': 2021}
# 2025-04-19 11:30:35,631 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,631 INFO sqlalchemy.engine.Engine [cached since 1.838s ago] {'net_migration': 17261, 'county_fips': '48503', 'year': 2021}
# 2025-04-19 11:30:35,631 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,632 INFO sqlalchemy.engine.Engine [cached since 1.839s ago] {'net_migration': 11335, 'county_fips': '48505', 'year': 2021}
# 2025-04-19 11:30:35,632 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET net_migration = %(net_migration)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:30:35,633 INFO sqlalchemy.engine.Engine [cached since 1.839s ago] {'net_migration': 8805, 'county_fips': '48507', 'year': 2021}
# 2025-04-19 11:30:35,633 INFO sqlalchemy.engine.Engine COMMIT
# ✅ IRS net migration data for 2016–2020 loaded into economic_indicators table.
