# %%
# Jupyter Notebook: Load BEA Personal Income to economic_indicators Table

import os
from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.engine import URL
import requests

# Load environment variables
load_dotenv()

# Database connection
DB_NAME = os.environ["DB_NAME"]
DB_USER = os.environ["DB_USER"]
DB_PASSWORD = os.environ["DB_PASSWORD"]
DB_HOST = os.environ.get("DB_HOST", "localhost")
DB_PORT = os.environ.get("DB_PORT", "5432")

# BEA API Key
BEA_API_KEY = os.environ["BEA_API_KEY"]

# Create engine
connection_url = URL.create(
    "postgresql+psycopg2",
    username=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT,
    database=DB_NAME,
)
engine = create_engine(connection_url, echo=True)

# ----------------------------------------
# Query BEA API for Personal Income
# ----------------------------------------

def fetch_bea_income(year):
    url = "https://apps.bea.gov/api/data"
    params = {
        "UserID": BEA_API_KEY,
        "method": "GetData",
        "datasetname": "Regional",
        "TableName": "CAINC1",
        "LineCode": "3",  # Personal income
        "GeoFIPS": "COUNTY",
        "Year": str(year),
        "ResultFormat": "json"
    }

    resp = requests.get(url, params=params)
    try:
        results = resp.json()["BEAAPI"]["Results"]["Data"]
    except KeyError:
        print("❌ Could not find expected 'Data' field.")
        print("Response:", resp.json())
        return pd.DataFrame()

    records = [r for r in results if r["GeoFips"].isdigit() and len(r["GeoFips"]) == 5]
    df = pd.DataFrame(records)
    df = df[["GeoFips", "TimePeriod", "DataValue"]]
    df.columns = ["county_fips", "year", "personal_income"]
    df["county_fips"] = df["county_fips"].astype(str).str.zfill(5)
    df["year"] = df["year"].astype(int)
    df["personal_income"] = df["personal_income"].str.replace(",", "").astype(float)

    return df

# Fetch data from 2015 to 2020
all_years = [fetch_bea_income(y) for y in range(2015, 2021)]
bea_df = pd.concat(all_years)

# Check for matches before updating
with engine.begin() as conn:
    result = conn.execute(text("SELECT county_fips, year FROM economic_indicators"))
    existing_keys = set((row["county_fips"], row["year"]) for row in result.mappings())

# Filter BEA data to matching keys
bea_df = bea_df[bea_df.apply(lambda row: (row["county_fips"], row["year"]) in existing_keys, axis=1)]

# Update personal_income in economic_indicators
with engine.begin() as conn:
    for _, row in bea_df.iterrows():
        conn.execute(
            text("""
                UPDATE economic_indicators
                SET personal_income = :personal_income
                WHERE county_fips = :county_fips AND year = :year
            """),
            {
                "personal_income": row["personal_income"],
                "county_fips": row["county_fips"],
                "year": row["year"]
            }
        )

print("✅ BEA personal income data successfully loaded into economic_indicators table.")
# Out:
# 2025-04-19 11:21:08,203 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-04-19 11:21:08,203 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-19 11:21:08,204 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-04-19 11:21:08,204 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-19 11:21:08,205 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-04-19 11:21:08,205 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-19 11:21:08,206 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-19 11:21:08,206 INFO sqlalchemy.engine.Engine SELECT county_fips, year FROM economic_indicators
# 2025-04-19 11:21:08,206 INFO sqlalchemy.engine.Engine [generated in 0.00027s] {}
# 2025-04-19 11:21:08,210 INFO sqlalchemy.engine.Engine COMMIT
# 2025-04-19 11:21:08,297 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-19 11:21:08,298 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,299 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {'personal_income': 38156.0, 'county_fips': '08001', 'year': 2015}
# 2025-04-19 11:21:08,300 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,300 INFO sqlalchemy.engine.Engine [cached since 0.001902s ago] {'personal_income': 34241.0, 'county_fips': '08003', 'year': 2015}
# 2025-04-19 11:21:08,301 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,301 INFO sqlalchemy.engine.Engine [cached since 0.002828s ago] {'personal_income': 54023.0, 'county_fips': '08005', 'year': 2015}
# 2025-04-19 11:21:08,302 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,302 INFO sqlalchemy.engine.Engine [cached since 0.003821s ago] {'personal_income': 40564.0, 'county_fips': '08007', 'year': 2015}
# 2025-04-19 11:21:08,303 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,303 INFO sqlalchemy.engine.Engine [cached since 0.004771s ago] {'personal_income': 37807.0, 'county_fips': '08009', 'year': 2015}
# 2025-04-19 11:21:08,304 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,304 INFO sqlalchemy.engine.Engine [cached since 0.005656s ago] {'personal_income': 24723.0, 'county_fips': '08011', 'year': 2015}
# 2025-04-19 11:21:08,305 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,305 INFO sqlalchemy.engine.Engine [cached since 0.006563s ago] {'personal_income': 63236.0, 'county_fips': '08013', 'year': 2015}
# 2025-04-19 11:21:08,306 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,306 INFO sqlalchemy.engine.Engine [cached since 0.007445s ago] {'personal_income': 57982.0, 'county_fips': '08014', 'year': 2015}
# 2025-04-19 11:21:08,306 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,307 INFO sqlalchemy.engine.Engine [cached since 0.008204s ago] {'personal_income': 41571.0, 'county_fips': '08015', 'year': 2015}
# 2025-04-19 11:21:08,307 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,307 INFO sqlalchemy.engine.Engine [cached since 0.008972s ago] {'personal_income': 44306.0, 'county_fips': '08017', 'year': 2015}
# 2025-04-19 11:21:08,308 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,308 INFO sqlalchemy.engine.Engine [cached since 0.009719s ago] {'personal_income': 55801.0, 'county_fips': '08019', 'year': 2015}
# 2025-04-19 11:21:08,309 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,309 INFO sqlalchemy.engine.Engine [cached since 0.01051s ago] {'personal_income': 33563.0, 'county_fips': '08021', 'year': 2015}
# 2025-04-19 11:21:08,310 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,310 INFO sqlalchemy.engine.Engine [cached since 0.01148s ago] {'personal_income': 32792.0, 'county_fips': '08023', 'year': 2015}
# 2025-04-19 11:21:08,310 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,311 INFO sqlalchemy.engine.Engine [cached since 0.01252s ago] {'personal_income': 21007.0, 'county_fips': '08025', 'year': 2015}
# 2025-04-19 11:21:08,311 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,312 INFO sqlalchemy.engine.Engine [cached since 0.01341s ago] {'personal_income': 43685.0, 'county_fips': '08027', 'year': 2015}
# 2025-04-19 11:21:08,312 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,313 INFO sqlalchemy.engine.Engine [cached since 0.01425s ago] {'personal_income': 33611.0, 'county_fips': '08029', 'year': 2015}
# 2025-04-19 11:21:08,313 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,313 INFO sqlalchemy.engine.Engine [cached since 0.01507s ago] {'personal_income': 67464.0, 'county_fips': '08031', 'year': 2015}
# 2025-04-19 11:21:08,314 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,314 INFO sqlalchemy.engine.Engine [cached since 0.01585s ago] {'personal_income': 34093.0, 'county_fips': '08033', 'year': 2015}
# 2025-04-19 11:21:08,315 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,315 INFO sqlalchemy.engine.Engine [cached since 0.01673s ago] {'personal_income': 61453.0, 'county_fips': '08035', 'year': 2015}
# 2025-04-19 11:21:08,316 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,316 INFO sqlalchemy.engine.Engine [cached since 0.01763s ago] {'personal_income': 65416.0, 'county_fips': '08037', 'year': 2015}
# 2025-04-19 11:21:08,317 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,317 INFO sqlalchemy.engine.Engine [cached since 0.01879s ago] {'personal_income': 52158.0, 'county_fips': '08039', 'year': 2015}
# 2025-04-19 11:21:08,318 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,318 INFO sqlalchemy.engine.Engine [cached since 0.01964s ago] {'personal_income': 44144.0, 'county_fips': '08041', 'year': 2015}
# 2025-04-19 11:21:08,319 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,319 INFO sqlalchemy.engine.Engine [cached since 0.02046s ago] {'personal_income': 30758.0, 'county_fips': '08043', 'year': 2015}
# 2025-04-19 11:21:08,319 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,320 INFO sqlalchemy.engine.Engine [cached since 0.02129s ago] {'personal_income': 54281.0, 'county_fips': '08045', 'year': 2015}
# 2025-04-19 11:21:08,320 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,320 INFO sqlalchemy.engine.Engine [cached since 0.02211s ago] {'personal_income': 46078.0, 'county_fips': '08047', 'year': 2015}
# 2025-04-19 11:21:08,321 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,321 INFO sqlalchemy.engine.Engine [cached since 0.02304s ago] {'personal_income': 46276.0, 'county_fips': '08049', 'year': 2015}
# 2025-04-19 11:21:08,322 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,322 INFO sqlalchemy.engine.Engine [cached since 0.02384s ago] {'personal_income': 42609.0, 'county_fips': '08051', 'year': 2015}
# 2025-04-19 11:21:08,323 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,323 INFO sqlalchemy.engine.Engine [cached since 0.02464s ago] {'personal_income': 44733.0, 'county_fips': '08053', 'year': 2015}
# 2025-04-19 11:21:08,324 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,324 INFO sqlalchemy.engine.Engine [cached since 0.02562s ago] {'personal_income': 36816.0, 'county_fips': '08055', 'year': 2015}
# 2025-04-19 11:21:08,325 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,325 INFO sqlalchemy.engine.Engine [cached since 0.02652s ago] {'personal_income': 48228.0, 'county_fips': '08057', 'year': 2015}
# 2025-04-19 11:21:08,325 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,326 INFO sqlalchemy.engine.Engine [cached since 0.02733s ago] {'personal_income': 55942.0, 'county_fips': '08059', 'year': 2015}
# 2025-04-19 11:21:08,326 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,327 INFO sqlalchemy.engine.Engine [cached since 0.02825s ago] {'personal_income': 45552.0, 'county_fips': '08061', 'year': 2015}
# 2025-04-19 11:21:08,327 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,327 INFO sqlalchemy.engine.Engine [cached since 0.02905s ago] {'personal_income': 34580.0, 'county_fips': '08063', 'year': 2015}
# 2025-04-19 11:21:08,328 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,328 INFO sqlalchemy.engine.Engine [cached since 0.02984s ago] {'personal_income': 33486.0, 'county_fips': '08065', 'year': 2015}
# 2025-04-19 11:21:08,329 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,329 INFO sqlalchemy.engine.Engine [cached since 0.03071s ago] {'personal_income': 53767.0, 'county_fips': '08067', 'year': 2015}
# 2025-04-19 11:21:08,330 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,330 INFO sqlalchemy.engine.Engine [cached since 0.03189s ago] {'personal_income': 46446.0, 'county_fips': '08069', 'year': 2015}
# 2025-04-19 11:21:08,331 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,332 INFO sqlalchemy.engine.Engine [cached since 0.03328s ago] {'personal_income': 34645.0, 'county_fips': '08071', 'year': 2015}
# 2025-04-19 11:21:08,332 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,333 INFO sqlalchemy.engine.Engine [cached since 0.03446s ago] {'personal_income': 27786.0, 'county_fips': '08073', 'year': 2015}
# 2025-04-19 11:21:08,334 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,334 INFO sqlalchemy.engine.Engine [cached since 0.03558s ago] {'personal_income': 48062.0, 'county_fips': '08075', 'year': 2015}
# 2025-04-19 11:21:08,335 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,335 INFO sqlalchemy.engine.Engine [cached since 0.03652s ago] {'personal_income': 40295.0, 'county_fips': '08077', 'year': 2015}
# 2025-04-19 11:21:08,335 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,336 INFO sqlalchemy.engine.Engine [cached since 0.03737s ago] {'personal_income': 56811.0, 'county_fips': '08079', 'year': 2015}
# 2025-04-19 11:21:08,336 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,337 INFO sqlalchemy.engine.Engine [cached since 0.03823s ago] {'personal_income': 39672.0, 'county_fips': '08081', 'year': 2015}
# 2025-04-19 11:21:08,337 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,337 INFO sqlalchemy.engine.Engine [cached since 0.03914s ago] {'personal_income': 40524.0, 'county_fips': '08083', 'year': 2015}
# 2025-04-19 11:21:08,338 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,338 INFO sqlalchemy.engine.Engine [cached since 0.04012s ago] {'personal_income': 36355.0, 'county_fips': '08085', 'year': 2015}
# 2025-04-19 11:21:08,339 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,339 INFO sqlalchemy.engine.Engine [cached since 0.0411s ago] {'personal_income': 40368.0, 'county_fips': '08087', 'year': 2015}
# 2025-04-19 11:21:08,340 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,340 INFO sqlalchemy.engine.Engine [cached since 0.04206s ago] {'personal_income': 33585.0, 'county_fips': '08089', 'year': 2015}
# 2025-04-19 11:21:08,341 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,341 INFO sqlalchemy.engine.Engine [cached since 0.04319s ago] {'personal_income': 53780.0, 'county_fips': '08091', 'year': 2015}
# 2025-04-19 11:21:08,342 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,343 INFO sqlalchemy.engine.Engine [cached since 0.04426s ago] {'personal_income': 41565.0, 'county_fips': '08093', 'year': 2015}
# 2025-04-19 11:21:08,344 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,344 INFO sqlalchemy.engine.Engine [cached since 0.04595s ago] {'personal_income': 37100.0, 'county_fips': '08095', 'year': 2015}
# 2025-04-19 11:21:08,345 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,346 INFO sqlalchemy.engine.Engine [cached since 0.04732s ago] {'personal_income': 128818.0, 'county_fips': '08097', 'year': 2015}
# 2025-04-19 11:21:08,347 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,347 INFO sqlalchemy.engine.Engine [cached since 0.04868s ago] {'personal_income': 39723.0, 'county_fips': '08099', 'year': 2015}
# 2025-04-19 11:21:08,348 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,348 INFO sqlalchemy.engine.Engine [cached since 0.04999s ago] {'personal_income': 34570.0, 'county_fips': '08101', 'year': 2015}
# 2025-04-19 11:21:08,349 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,349 INFO sqlalchemy.engine.Engine [cached since 0.05117s ago] {'personal_income': 44718.0, 'county_fips': '08103', 'year': 2015}
# 2025-04-19 11:21:08,351 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,351 INFO sqlalchemy.engine.Engine [cached since 0.05249s ago] {'personal_income': 40709.0, 'county_fips': '08105', 'year': 2015}
# 2025-04-19 11:21:08,352 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,352 INFO sqlalchemy.engine.Engine [cached since 0.05366s ago] {'personal_income': 69663.0, 'county_fips': '08107', 'year': 2015}
# 2025-04-19 11:21:08,353 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,353 INFO sqlalchemy.engine.Engine [cached since 0.05485s ago] {'personal_income': 34720.0, 'county_fips': '08109', 'year': 2015}
# 2025-04-19 11:21:08,354 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,354 INFO sqlalchemy.engine.Engine [cached since 0.05609s ago] {'personal_income': 56446.0, 'county_fips': '08111', 'year': 2015}
# 2025-04-19 11:21:08,355 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,356 INFO sqlalchemy.engine.Engine [cached since 0.05723s ago] {'personal_income': 75795.0, 'county_fips': '08113', 'year': 2015}
# 2025-04-19 11:21:08,356 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,357 INFO sqlalchemy.engine.Engine [cached since 0.05846s ago] {'personal_income': 42651.0, 'county_fips': '08115', 'year': 2015}
# 2025-04-19 11:21:08,358 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,358 INFO sqlalchemy.engine.Engine [cached since 0.0597s ago] {'personal_income': 59335.0, 'county_fips': '08117', 'year': 2015}
# 2025-04-19 11:21:08,359 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,359 INFO sqlalchemy.engine.Engine [cached since 0.06081s ago] {'personal_income': 46538.0, 'county_fips': '08119', 'year': 2015}
# 2025-04-19 11:21:08,360 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,360 INFO sqlalchemy.engine.Engine [cached since 0.06192s ago] {'personal_income': 39697.0, 'county_fips': '08121', 'year': 2015}
# 2025-04-19 11:21:08,361 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,361 INFO sqlalchemy.engine.Engine [cached since 0.063s ago] {'personal_income': 43913.0, 'county_fips': '08123', 'year': 2015}
# 2025-04-19 11:21:08,362 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,362 INFO sqlalchemy.engine.Engine [cached since 0.06418s ago] {'personal_income': 50089.0, 'county_fips': '08125', 'year': 2015}
# 2025-04-19 11:21:08,363 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,364 INFO sqlalchemy.engine.Engine [cached since 0.06541s ago] {'personal_income': 32035.0, 'county_fips': '48001', 'year': 2015}
# 2025-04-19 11:21:08,365 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,365 INFO sqlalchemy.engine.Engine [cached since 0.06653s ago] {'personal_income': 45613.0, 'county_fips': '48003', 'year': 2015}
# 2025-04-19 11:21:08,366 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,366 INFO sqlalchemy.engine.Engine [cached since 0.06762s ago] {'personal_income': 37877.0, 'county_fips': '48005', 'year': 2015}
# 2025-04-19 11:21:08,367 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,367 INFO sqlalchemy.engine.Engine [cached since 0.06865s ago] {'personal_income': 47980.0, 'county_fips': '48007', 'year': 2015}
# 2025-04-19 11:21:08,368 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,368 INFO sqlalchemy.engine.Engine [cached since 0.06968s ago] {'personal_income': 47073.0, 'county_fips': '48009', 'year': 2015}
# 2025-04-19 11:21:08,369 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,369 INFO sqlalchemy.engine.Engine [cached since 0.0707s ago] {'personal_income': 41827.0, 'county_fips': '48011', 'year': 2015}
# 2025-04-19 11:21:08,370 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,370 INFO sqlalchemy.engine.Engine [cached since 0.07179s ago] {'personal_income': 37679.0, 'county_fips': '48013', 'year': 2015}
# 2025-04-19 11:21:08,373 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,374 INFO sqlalchemy.engine.Engine [cached since 0.07548s ago] {'personal_income': 50105.0, 'county_fips': '48015', 'year': 2015}
# 2025-04-19 11:21:08,375 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,375 INFO sqlalchemy.engine.Engine [cached since 0.07691s ago] {'personal_income': 42310.0, 'county_fips': '48017', 'year': 2015}
# 2025-04-19 11:21:08,376 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,376 INFO sqlalchemy.engine.Engine [cached since 0.07811s ago] {'personal_income': 45377.0, 'county_fips': '48019', 'year': 2015}
# 2025-04-19 11:21:08,377 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,377 INFO sqlalchemy.engine.Engine [cached since 0.07919s ago] {'personal_income': 33071.0, 'county_fips': '48021', 'year': 2015}
# 2025-04-19 11:21:08,378 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,379 INFO sqlalchemy.engine.Engine [cached since 0.08026s ago] {'personal_income': 42353.0, 'county_fips': '48023', 'year': 2015}
# 2025-04-19 11:21:08,379 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,380 INFO sqlalchemy.engine.Engine [cached since 0.08138s ago] {'personal_income': 28195.0, 'county_fips': '48025', 'year': 2015}
# 2025-04-19 11:21:08,381 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,381 INFO sqlalchemy.engine.Engine [cached since 0.08258s ago] {'personal_income': 41147.0, 'county_fips': '48027', 'year': 2015}
# 2025-04-19 11:21:08,383 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,383 INFO sqlalchemy.engine.Engine [cached since 0.08465s ago] {'personal_income': 42598.0, 'county_fips': '48029', 'year': 2015}
# 2025-04-19 11:21:08,384 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,384 INFO sqlalchemy.engine.Engine [cached since 0.08582s ago] {'personal_income': 50112.0, 'county_fips': '48031', 'year': 2015}
# 2025-04-19 11:21:08,385 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,385 INFO sqlalchemy.engine.Engine [cached since 0.08703s ago] {'personal_income': 50252.0, 'county_fips': '48033', 'year': 2015}
# 2025-04-19 11:21:08,386 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,386 INFO sqlalchemy.engine.Engine [cached since 0.08801s ago] {'personal_income': 38954.0, 'county_fips': '48035', 'year': 2015}
# 2025-04-19 11:21:08,387 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,387 INFO sqlalchemy.engine.Engine [cached since 0.08899s ago] {'personal_income': 37394.0, 'county_fips': '48037', 'year': 2015}
# 2025-04-19 11:21:08,388 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,388 INFO sqlalchemy.engine.Engine [cached since 0.09004s ago] {'personal_income': 46689.0, 'county_fips': '48039', 'year': 2015}
# 2025-04-19 11:21:08,389 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,389 INFO sqlalchemy.engine.Engine [cached since 0.09088s ago] {'personal_income': 35418.0, 'county_fips': '48041', 'year': 2015}
# 2025-04-19 11:21:08,390 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,390 INFO sqlalchemy.engine.Engine [cached since 0.09173s ago] {'personal_income': 41314.0, 'county_fips': '48043', 'year': 2015}
# 2025-04-19 11:21:08,391 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,391 INFO sqlalchemy.engine.Engine [cached since 0.09261s ago] {'personal_income': 34976.0, 'county_fips': '48045', 'year': 2015}
# 2025-04-19 11:21:08,392 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,392 INFO sqlalchemy.engine.Engine [cached since 0.09346s ago] {'personal_income': 34248.0, 'county_fips': '48047', 'year': 2015}
# 2025-04-19 11:21:08,392 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,393 INFO sqlalchemy.engine.Engine [cached since 0.09432s ago] {'personal_income': 35430.0, 'county_fips': '48049', 'year': 2015}
# 2025-04-19 11:21:08,393 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,393 INFO sqlalchemy.engine.Engine [cached since 0.09518s ago] {'personal_income': 42859.0, 'county_fips': '48051', 'year': 2015}
# 2025-04-19 11:21:08,394 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,394 INFO sqlalchemy.engine.Engine [cached since 0.09608s ago] {'personal_income': 44255.0, 'county_fips': '48053', 'year': 2015}
# 2025-04-19 11:21:08,395 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,395 INFO sqlalchemy.engine.Engine [cached since 0.09719s ago] {'personal_income': 31122.0, 'county_fips': '48055', 'year': 2015}
# 2025-04-19 11:21:08,396 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,397 INFO sqlalchemy.engine.Engine [cached since 0.09819s ago] {'personal_income': 38853.0, 'county_fips': '48057', 'year': 2015}
# 2025-04-19 11:21:08,397 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,398 INFO sqlalchemy.engine.Engine [cached since 0.0993s ago] {'personal_income': 38254.0, 'county_fips': '48059', 'year': 2015}
# 2025-04-19 11:21:08,398 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,399 INFO sqlalchemy.engine.Engine [cached since 0.1003s ago] {'personal_income': 26745.0, 'county_fips': '48061', 'year': 2015}
# 2025-04-19 11:21:08,399 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,400 INFO sqlalchemy.engine.Engine [cached since 0.1013s ago] {'personal_income': 40501.0, 'county_fips': '48063', 'year': 2015}
# 2025-04-19 11:21:08,400 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,401 INFO sqlalchemy.engine.Engine [cached since 0.1023s ago] {'personal_income': 42365.0, 'county_fips': '48065', 'year': 2015}
# 2025-04-19 11:21:08,401 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,402 INFO sqlalchemy.engine.Engine [cached since 0.1033s ago] {'personal_income': 35457.0, 'county_fips': '48067', 'year': 2015}
# 2025-04-19 11:21:08,402 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,403 INFO sqlalchemy.engine.Engine [cached since 0.1044s ago] {'personal_income': 73108.0, 'county_fips': '48069', 'year': 2015}
# 2025-04-19 11:21:08,404 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,404 INFO sqlalchemy.engine.Engine [cached since 0.1055s ago] {'personal_income': 50406.0, 'county_fips': '48071', 'year': 2015}
# 2025-04-19 11:21:08,404 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,405 INFO sqlalchemy.engine.Engine [cached since 0.1065s ago] {'personal_income': 33429.0, 'county_fips': '48073', 'year': 2015}
# 2025-04-19 11:21:08,405 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,406 INFO sqlalchemy.engine.Engine [cached since 0.1075s ago] {'personal_income': 27846.0, 'county_fips': '48075', 'year': 2015}
# 2025-04-19 11:21:08,406 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,407 INFO sqlalchemy.engine.Engine [cached since 0.1084s ago] {'personal_income': 41306.0, 'county_fips': '48077', 'year': 2015}
# 2025-04-19 11:21:08,407 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,408 INFO sqlalchemy.engine.Engine [cached since 0.1093s ago] {'personal_income': 33451.0, 'county_fips': '48079', 'year': 2015}
# 2025-04-19 11:21:08,408 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,409 INFO sqlalchemy.engine.Engine [cached since 0.1102s ago] {'personal_income': 39599.0, 'county_fips': '48081', 'year': 2015}
# 2025-04-19 11:21:08,409 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,409 INFO sqlalchemy.engine.Engine [cached since 0.1111s ago] {'personal_income': 40511.0, 'county_fips': '48083', 'year': 2015}
# 2025-04-19 11:21:08,410 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,410 INFO sqlalchemy.engine.Engine [cached since 0.112s ago] {'personal_income': 60973.0, 'county_fips': '48085', 'year': 2015}
# 2025-04-19 11:21:08,411 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,411 INFO sqlalchemy.engine.Engine [cached since 0.1129s ago] {'personal_income': 39050.0, 'county_fips': '48087', 'year': 2015}
# 2025-04-19 11:21:08,412 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,412 INFO sqlalchemy.engine.Engine [cached since 0.1138s ago] {'personal_income': 44805.0, 'county_fips': '48089', 'year': 2015}
# 2025-04-19 11:21:08,413 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,413 INFO sqlalchemy.engine.Engine [cached since 0.1146s ago] {'personal_income': 55089.0, 'county_fips': '48091', 'year': 2015}
# 2025-04-19 11:21:08,414 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,414 INFO sqlalchemy.engine.Engine [cached since 0.1155s ago] {'personal_income': 36995.0, 'county_fips': '48093', 'year': 2015}
# 2025-04-19 11:21:08,414 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,415 INFO sqlalchemy.engine.Engine [cached since 0.1165s ago] {'personal_income': 20856.0, 'county_fips': '48095', 'year': 2015}
# 2025-04-19 11:21:08,415 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,416 INFO sqlalchemy.engine.Engine [cached since 0.1174s ago] {'personal_income': 48503.0, 'county_fips': '48097', 'year': 2015}
# 2025-04-19 11:21:08,416 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,417 INFO sqlalchemy.engine.Engine [cached since 0.1183s ago] {'personal_income': 30517.0, 'county_fips': '48099', 'year': 2015}
# 2025-04-19 11:21:08,417 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,418 INFO sqlalchemy.engine.Engine [cached since 0.1193s ago] {'personal_income': 50425.0, 'county_fips': '48101', 'year': 2015}
# 2025-04-19 11:21:08,418 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,418 INFO sqlalchemy.engine.Engine [cached since 0.1201s ago] {'personal_income': 40773.0, 'county_fips': '48103', 'year': 2015}
# 2025-04-19 11:21:08,419 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,419 INFO sqlalchemy.engine.Engine [cached since 0.1208s ago] {'personal_income': 38729.0, 'county_fips': '48105', 'year': 2015}
# 2025-04-19 11:21:08,420 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,420 INFO sqlalchemy.engine.Engine [cached since 0.1215s ago] {'personal_income': 31008.0, 'county_fips': '48107', 'year': 2015}
# 2025-04-19 11:21:08,420 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,421 INFO sqlalchemy.engine.Engine [cached since 0.1223s ago] {'personal_income': 39330.0, 'county_fips': '48109', 'year': 2015}
# 2025-04-19 11:21:08,421 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,421 INFO sqlalchemy.engine.Engine [cached since 0.123s ago] {'personal_income': 72204.0, 'county_fips': '48111', 'year': 2015}
# 2025-04-19 11:21:08,422 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:08,422 INFO sqlalchemy.engine.Engine [cached since 0.1239s ago] {'personal_income': 52036.0, 'county_fips': '48113', 'year': 2015}
# ...
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,159 INFO sqlalchemy.engine.Engine [cached since 1.861s ago] {'personal_income': 31627.0, 'county_fips': '48427', 'year': 2020}
# 2025-04-19 11:21:10,160 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,160 INFO sqlalchemy.engine.Engine [cached since 1.862s ago] {'personal_income': 43862.0, 'county_fips': '48429', 'year': 2020}
# 2025-04-19 11:21:10,161 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,161 INFO sqlalchemy.engine.Engine [cached since 1.863s ago] {'personal_income': 58881.0, 'county_fips': '48431', 'year': 2020}
# 2025-04-19 11:21:10,161 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,162 INFO sqlalchemy.engine.Engine [cached since 1.863s ago] {'personal_income': 73788.0, 'county_fips': '48433', 'year': 2020}
# 2025-04-19 11:21:10,162 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,163 INFO sqlalchemy.engine.Engine [cached since 1.864s ago] {'personal_income': 66088.0, 'county_fips': '48435', 'year': 2020}
# 2025-04-19 11:21:10,163 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,164 INFO sqlalchemy.engine.Engine [cached since 1.866s ago] {'personal_income': 60049.0, 'county_fips': '48437', 'year': 2020}
# 2025-04-19 11:21:10,164 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,165 INFO sqlalchemy.engine.Engine [cached since 1.866s ago] {'personal_income': 53801.0, 'county_fips': '48439', 'year': 2020}
# 2025-04-19 11:21:10,165 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,166 INFO sqlalchemy.engine.Engine [cached since 1.867s ago] {'personal_income': 49459.0, 'county_fips': '48441', 'year': 2020}
# 2025-04-19 11:21:10,166 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,167 INFO sqlalchemy.engine.Engine [cached since 1.868s ago] {'personal_income': 54943.0, 'county_fips': '48443', 'year': 2020}
# 2025-04-19 11:21:10,167 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,168 INFO sqlalchemy.engine.Engine [cached since 1.869s ago] {'personal_income': 42433.0, 'county_fips': '48445', 'year': 2020}
# 2025-04-19 11:21:10,168 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,169 INFO sqlalchemy.engine.Engine [cached since 1.87s ago] {'personal_income': 44564.0, 'county_fips': '48447', 'year': 2020}
# 2025-04-19 11:21:10,169 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,170 INFO sqlalchemy.engine.Engine [cached since 1.871s ago] {'personal_income': 42440.0, 'county_fips': '48449', 'year': 2020}
# 2025-04-19 11:21:10,170 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,171 INFO sqlalchemy.engine.Engine [cached since 1.872s ago] {'personal_income': 55232.0, 'county_fips': '48451', 'year': 2020}
# 2025-04-19 11:21:10,172 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,172 INFO sqlalchemy.engine.Engine [cached since 1.874s ago] {'personal_income': 72109.0, 'county_fips': '48453', 'year': 2020}
# 2025-04-19 11:21:10,173 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,173 INFO sqlalchemy.engine.Engine [cached since 1.875s ago] {'personal_income': 43566.0, 'county_fips': '48455', 'year': 2020}
# 2025-04-19 11:21:10,174 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,174 INFO sqlalchemy.engine.Engine [cached since 1.876s ago] {'personal_income': 39559.0, 'county_fips': '48457', 'year': 2020}
# 2025-04-19 11:21:10,175 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,175 INFO sqlalchemy.engine.Engine [cached since 1.877s ago] {'personal_income': 40758.0, 'county_fips': '48459', 'year': 2020}
# 2025-04-19 11:21:10,176 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,176 INFO sqlalchemy.engine.Engine [cached since 1.878s ago] {'personal_income': 54938.0, 'county_fips': '48461', 'year': 2020}
# 2025-04-19 11:21:10,177 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,177 INFO sqlalchemy.engine.Engine [cached since 1.879s ago] {'personal_income': 47479.0, 'county_fips': '48463', 'year': 2020}
# 2025-04-19 11:21:10,178 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,178 INFO sqlalchemy.engine.Engine [cached since 1.88s ago] {'personal_income': 42518.0, 'county_fips': '48465', 'year': 2020}
# 2025-04-19 11:21:10,179 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,179 INFO sqlalchemy.engine.Engine [cached since 1.881s ago] {'personal_income': 42067.0, 'county_fips': '48467', 'year': 2020}
# 2025-04-19 11:21:10,180 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,180 INFO sqlalchemy.engine.Engine [cached since 1.882s ago] {'personal_income': 53179.0, 'county_fips': '48469', 'year': 2020}
# 2025-04-19 11:21:10,181 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,181 INFO sqlalchemy.engine.Engine [cached since 1.883s ago] {'personal_income': 30669.0, 'county_fips': '48471', 'year': 2020}
# 2025-04-19 11:21:10,182 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,182 INFO sqlalchemy.engine.Engine [cached since 1.884s ago] {'personal_income': 47396.0, 'county_fips': '48473', 'year': 2020}
# 2025-04-19 11:21:10,183 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,183 INFO sqlalchemy.engine.Engine [cached since 1.885s ago] {'personal_income': 48672.0, 'county_fips': '48475', 'year': 2020}
# 2025-04-19 11:21:10,184 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,184 INFO sqlalchemy.engine.Engine [cached since 1.886s ago] {'personal_income': 58797.0, 'county_fips': '48477', 'year': 2020}
# 2025-04-19 11:21:10,185 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,185 INFO sqlalchemy.engine.Engine [cached since 1.887s ago] {'personal_income': 36739.0, 'county_fips': '48479', 'year': 2020}
# 2025-04-19 11:21:10,186 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,186 INFO sqlalchemy.engine.Engine [cached since 1.888s ago] {'personal_income': 48537.0, 'county_fips': '48481', 'year': 2020}
# 2025-04-19 11:21:10,187 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,187 INFO sqlalchemy.engine.Engine [cached since 1.889s ago] {'personal_income': 45897.0, 'county_fips': '48483', 'year': 2020}
# 2025-04-19 11:21:10,188 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,188 INFO sqlalchemy.engine.Engine [cached since 1.89s ago] {'personal_income': 46869.0, 'county_fips': '48485', 'year': 2020}
# 2025-04-19 11:21:10,189 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,189 INFO sqlalchemy.engine.Engine [cached since 1.89s ago] {'personal_income': 54076.0, 'county_fips': '48487', 'year': 2020}
# 2025-04-19 11:21:10,189 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,190 INFO sqlalchemy.engine.Engine [cached since 1.891s ago] {'personal_income': 32727.0, 'county_fips': '48489', 'year': 2020}
# 2025-04-19 11:21:10,190 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,190 INFO sqlalchemy.engine.Engine [cached since 1.892s ago] {'personal_income': 57509.0, 'county_fips': '48491', 'year': 2020}
# 2025-04-19 11:21:10,191 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,191 INFO sqlalchemy.engine.Engine [cached since 1.893s ago] {'personal_income': 51291.0, 'county_fips': '48493', 'year': 2020}
# 2025-04-19 11:21:10,192 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,192 INFO sqlalchemy.engine.Engine [cached since 1.894s ago] {'personal_income': 59302.0, 'county_fips': '48495', 'year': 2020}
# 2025-04-19 11:21:10,193 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,193 INFO sqlalchemy.engine.Engine [cached since 1.895s ago] {'personal_income': 50487.0, 'county_fips': '48497', 'year': 2020}
# 2025-04-19 11:21:10,194 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,194 INFO sqlalchemy.engine.Engine [cached since 1.896s ago] {'personal_income': 44788.0, 'county_fips': '48499', 'year': 2020}
# 2025-04-19 11:21:10,195 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,195 INFO sqlalchemy.engine.Engine [cached since 1.897s ago] {'personal_income': 48354.0, 'county_fips': '48501', 'year': 2020}
# 2025-04-19 11:21:10,196 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,196 INFO sqlalchemy.engine.Engine [cached since 1.898s ago] {'personal_income': 53109.0, 'county_fips': '48503', 'year': 2020}
# 2025-04-19 11:21:10,197 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,197 INFO sqlalchemy.engine.Engine [cached since 1.899s ago] {'personal_income': 29730.0, 'county_fips': '48505', 'year': 2020}
# 2025-04-19 11:21:10,198 INFO sqlalchemy.engine.Engine
#                 UPDATE economic_indicators
#                 SET personal_income = %(personal_income)s
#                 WHERE county_fips = %(county_fips)s AND year = %(year)s
#
# 2025-04-19 11:21:10,198 INFO sqlalchemy.engine.Engine [cached since 1.9s ago] {'personal_income': 39161.0, 'county_fips': '48507', 'year': 2020}
# 2025-04-19 11:21:10,199 INFO sqlalchemy.engine.Engine COMMIT
# ✅ BEA personal income data successfully loaded into economic_indicators table.
